# %% [markdown]
# <a href="https://colab.research.google.com/github/ALI16572/python_projects_colab/blob/main/power_calculator_(While).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter a number:")) # 6
a = int(input("Enter a power:")) # 2
result = 1
i = 1
while i<=a:
  result *= n
  i += 1
  print("answer = ",result)
# Out:
# Enter a number:5
# Enter a power:2
# answer =  5
# answer =  25

# %%
a = int(input("Enter a number:"))
b = int(input("Enter a power:"))
result = 1
i = 1
while i<=b:
  result *= a
  i += 1
  print("answer = ",result)
# Out:
# Enter a number:5
# Enter a power:2
# answer =  5
# answer =  25
