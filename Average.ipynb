# %% [markdown]
# <a href="https://colab.research.google.com/github/ALI16572/python_projects_colab/blob/main/Average.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1
mean = 38
wrong_number = 36
correct_number = 56
total_number = 40
sum = mean*total_number
num2 = sum-((wrong_number)-(correct_number))
mean2 = num2/total_number
print(mean2)
# Out:
# 38.5

# %%
# 2
a = 38
b = 36
c = 56
d = 40
sum = a*d
num2 = sum -((b)-(c))
mean = num2/d
print(mean2)
# Out:
# 38.5
