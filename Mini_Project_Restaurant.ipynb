# %% [markdown]
# <a href="https://colab.research.google.com/github/ALI16572/python_projects_colab/blob/main/Mini_Project_Restaurant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Define the menu of restaurant
menu = {

        'pizza':40,
        'pasta':50,
        'burger':60,
        'salad':70,
        'ice cream':80,
        'coffee':90,
}

# Greet
print("welcome to our python restaurant")
print("""
pizza: $40
pasta: $50
burger: $60
salad: $70
ice Cream: $80
coffee: $90
""")
order_total = 0
# For Example 80 + 50 = 130
item_1 = input("Enter the name of item you want to order = ")
if item_1 in menu:
  order_total = order_total + menu[item_1] # 0 + 50
  print(f"Your item {item_1} has been added to your order")
else:
    print(f"Ordered item {item_1} is not available yet!")

another_order = input("Do you want to add another item? (yes/no)")
if another_order  == "yes":
  item_2 = input("Enter the name of second item =  ")
  if item_2 in menu:
    order_total += menu [item_2]
  else:
    print(f"Ordered item {item_2} is not available yet!")

print(f"The total amout of item to pay is {order_total}")
# Out:
# welcome to our python restaurant
#
# pizza: $40
# pasta: $50
# burger: $60
# salad: $70
# ice Cream: $80
# coffee: $90
#
# Enter the name of item you want to order = pasta
# Your item pasta has been added to your order
# Do you want to add another item? (yes/no)yes
# Enter the name of second item =  pizza
# The total amout of item to pay is 90
