# %% [markdown]
# <a href="https://colab.research.google.com/github/ALI16572/python_projects_colab/blob/main/Reverse_Order_(While_Loop).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to count total digits in a number using while loop

num = int(input("Enter a number: "))

# Convert negative number to positive
if num < 0:
    num = -num

count = 0

# Special case if number is 0
if num == 0:
    count = 1
else:
    while num > 0:
        num = num // 10   # Remove last digit
        count += 1

print("Total digits:", count)
