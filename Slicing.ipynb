# %% [markdown]
# <a href="https://colab.research.google.com/github/ALI16572/python_projects_colab/blob/main/Slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text =  "aliammar"
print(text[-1:-5:-3])
# Out:
# rm

# %%
text = "helloworld"
print(text[1:5:3])
# Out:
# eo
