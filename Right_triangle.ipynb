# %% [markdown]
# <a href="https://colab.research.google.com/github/ALI16572/python_projects_colab/blob/main/Right_triangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rows = 4
for i in range(1, rows + 1):
    for j in range(rows - i):
        print(" ", end="")
    for k in range(i):
        print("*", end="")
    print()
# Out:
#    *
#   **
#  ***
# ****
